# %% [markdown]
# # ODE Exercises

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from IPython.html.widgets import interact, interactive
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Question 1
# For this question refer to the solutions for the simple pendulum we got using scipy's odeint from the beginning of the ODE Tour.
#
# (a) See what happens to the period of the pendulum as you change the initial angle of release. Plot θ vs t for 5 different initial angles, θ\_0 , spanning 0 to π. (i.e. 0, π/4 , π/2 , 3π/4 , and π ). Put them all on the same plot. What happens to the period of the pendulum as the initial angle increases from π/4 to 3π/4? What happens to the trajectory when the initial angle is 0 and π ?
#
#
# (b) Make plots of θ vs. t, ω vs. t, and ω vs. θ (the so-called "phase plot") for θ\_0 = 0.95π. Look carefully at their behavior. What is going on in these figures?
#
#
# (c) For the θ\_0 = 0.95π case, check that energy is conserved by plotting E/m vs. t (where E=mgℓcos(θ)+0.5m(ωr)2).
# Is the energy a constant? If not, then the computational errors are producing a non-physical loss (or gain) of energy. Review the documentation for odeint and change the error tolerance value to a tighter number.
#
# (d) Now look at what happens if we start the pendulum straight up, θ=π. Go for at least 50 s. Be sure to describe what happens numerically according to the θ vs. t, ω vs. t and E/m vs. t plots. What do you think should happen? What happens if you change the error tolerance on odeint? How does this compare to a nearly vertical pendulum: θ\_0=π−0.000001 ?

# %%
#a
def deriv(theta_current,t):
    g=9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])

th0 = 0
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
theta_init0 = np.array([th0, omega0])
theta0 = odeint(deriv,theta_init0,t)

th0 = pi/4.
theta_init1 = np.array([th0, omega0])
theta1 = odeint(deriv,theta_init1,t)

th0 = pi/2.
theta_init2 = np.array([th0, omega0])
theta2 = odeint(deriv,theta_init2,t)

th0 = 3.*pi/4
theta_init3 = np.array([th0, omega0])
theta3 = odeint(deriv,theta_init3,t)

th0 = pi
theta_init4 = np.array([th0, omega0])
theta4 = odeint(deriv,theta_init4,t)

plt.plot(t, theta0[:,0], label='th0=0')
plt.plot(t, theta1[:,0], label='th0=pi/4')
plt.plot(t, theta2[:,0], label='th0=pi/2')
plt.plot(t, theta3[:,0], label='th0=3pi/4')
plt.plot(t, theta4[:,0], label='th0=pi')
plt.legend(loc='best', fontsize = 8)
plt.show()

# %%
#b
def deriv(theta_current,t):
    g=9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])
th0 = .95*pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
theta_init0 = np.array([th0, omega0])
theta = odeint(deriv,theta_init0,t)

plt.plot(t,theta[:,0])
plt.title('Theta vs t')
plt.figure()

plt.plot(t,theta[:,1])
plt.title('Omega vs t')
plt.figure()

plt.plot(theta[:,0], theta[:,1])
plt.title('Theta vs Omega')
plt.show()

# %%
#c
def deriv(theta_current,t):
    g=9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])
g=9.8
ell=0.5
th0 = .95*pi
t = np.arange(0.,10.+0.01,0.01)
omega0 = 0.
theta_init0 = np.array([th0, omega0])
theta = odeint(deriv,theta_init0,t,rtol=.9)

Em = g*ell*(1-np.cos(theta[:,0]))+0.5*(ell**2)*(theta[:,1]**2)

plt.plot(t, Em)
plt.title('E/m vs t')
plt.show()

# %%
#d
def deriv(theta_current,t):
    g=9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])
g=9.8
ell=0.5
th0 = pi
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0.
theta_init0 = np.array([th0, omega0])
theta = odeint(deriv,theta_init0,t,rtol=.9)

Em = g*ell*(1-np.cos(theta[:,0]))+0.5*(ell**2)*(theta[:,1]**2)


plt.plot(t,theta[:,0])
plt.title('Theta vs t')
plt.figure()

plt.plot(t,theta[:,1])
plt.title('Omega vs t')
plt.figure()

plt.plot(theta[:,0], theta[:,1])
plt.title('Theta vs Omega')
plt.show()


plt.plot(t, Em)
plt.title('E/m vs t')
plt.show()

# %%
def deriv(theta_current,t):
    g=9.8
    ell = 0.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell)*np.sin(theta)
    return np.array([dtheta, domega])
g=9.8
ell=0.5
th0 = pi-.000001
t = np.arange(0.,50.+0.01,0.01)
omega0 = 0.
theta_init0 = np.array([th0, omega0])
theta = odeint(deriv,theta_init0,t,rtol=None)

Em = g*ell*(1-np.cos(theta[:,0]))+0.5*(ell**2)*(theta[:,1]**2)


plt.plot(t,theta[:,0])
plt.title('Theta vs t')
plt.figure()

plt.plot(t,theta[:,1])
plt.title('Omega vs t')
plt.figure()

plt.plot(theta[:,0], theta[:,1])
plt.title('Theta vs Omega')
plt.show()

theta = odeint(deriv,theta_init0,t,rtol=.9)

Em = g*ell*(1-np.cos(theta[:,0]))+0.5*(ell**2)*(theta[:,1]**2)


plt.plot(t, Em)
plt.title('E/m vs t')
plt.show()

# %% [markdown]
# Question 2
# (a) Use Euler's method to solve the following first-order differential equation with given initial condition y(0) = 0.
#     dydx=x+2y
# Find the value of y when x = 1, that is y(1), using a first a step size of 0.25, and then 0.02.
#
# (b) Plot the results from part (a) for the two different step sizes with the exact solution
#     y=0.25e**(2x)−0.5x−0.25
# on one plot. Include a legend. Which step size gives a more accurate result?
#
# (c) Now solve the same problem using Euler-Cromer and the Midpoint method, using the same pair of step sizes and plot the results along with the exact solution. Instead of plotting the solutions, plot the difference between the approximate numerical solutions and the exact solution. Which combination of method and step-size gives the best result?

# %%
#a
xmax = 10
dx = 0.25
nsteps = int(xmax/dx)
x = np.zeros(nsteps)
y = np.zeros(nsteps)
 
y[0] = 0.

for i in range(len(x)-1):
    x[i+1] = x[i] + dx
    y[i+1] = y[i] + dx * (x[i] + 2*y[i])
print y[1/dx]
# Out:
# 0.515625

# %%
xmax1 = 10
dx1 = 0.02
nsteps = int(xmax1/dx1)
x1 = np.zeros(nsteps)
y1 = np.zeros(nsteps)
 
y1[0] = 0.

for i in range(len(x1)-1):
    x1[i+1] = x1[i] + dx1
    y1[i+1] = y1[i] + dx1 * (x1[i]+ 2*y1[i])
print y1[1/dx1]
# Out:
# 1.02667083657

# %%
#b
x2 = arange(0., 10.01, .01)
y2 = 0.25*np.exp(2*x2) - 0.5*x2 - 0.25

plt.plot(x,y, label = "steps of .25")
plt.plot(x1,y1, label = "steps of .02")
plt.plot(x2,y2, label = "actual")
plt.legend(loc='best')
plt.xlim(0,3)
plt.ylim(0,10)
plt.show()

# %%
#c

#E-C step size 0.25
xmax = 10
dx = 0.25
nsteps = int(xmax/dx)
x = np.zeros(nsteps)
y = np.zeros(nsteps)
 
y[0] = 0.

for i in range(len(x)-1):
    x[i+1] = x[i] + dx
    y[i+1] = y[i] + dx * (x[i+1] + 2*y[i])

#E-C step size .02
xmax = 10
dx1 = 0.02
nsteps = int(xmax/dx1)
x1 = np.zeros(nsteps)
y1 = np.zeros(nsteps)
 
y1[0] = 0.

for i in range(len(x1)-1):
    x1[i+1] = x1[i] + dx1
    y1[i+1] = y1[i] + dx1 * (x1[i+1] + 2*y1[i])

#Midpoint step size .25
xmax = 10
dx2 = 0.25
nsteps = int(xmax/dx2)
x2 = np.zeros(nsteps)
y2 = np.zeros(nsteps)
 
y2[0] = 0.

for i in range(len(x2)-1):
    x2[i+1] = x2[i] + dx2
    y2[i+1] = y2[i] + dx2 * .5*(x2[i]+x2[i+1]) + dx2*2*y2[i]

#Midpoint step size .02
xmax = 10
dx3 = 0.02
nsteps = int(xmax/dx3)
x3 = np.zeros(nsteps)
y3 = np.zeros(nsteps)
 
y3[0] = 0.

for i in range(len(x3)-1):
    x3[i+1] = x3[i] + dx3
    y3[i+1] = y3[i] + dx3 * .5*(x3[i]+x3[i+1]) + dx3*2*y3[i]
    
#real values    
x4 = arange(0, 10.,.25)
y4 = 0.25*np.exp(2*x4) - 0.5*x4 - 0.25
x5 = arange(0,10.,.02)
y5 = 0.25*np.exp(2*x5) - 0.5*x5 - 0.25

y6 = abs(y4-y)
y7 = abs(y5 - y1)
y8 = abs(y4 - y2)
y9 = abs(y5 - y3)

plt.plot(x4,y6, label='E-C step .25')
plt.plot(x5,y7, label='E-C step .02')
plt.plot(x4,y8, label='Midpoint step .25')
plt.plot(x5,y9, label='Midpoint step .02')
xlim(0,3)
ylim(0,10)
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %% [markdown]
# Euler-Cromer method with steps of .02 seems to be most accurate

# %% [markdown]
# Question 3
# We can use numerical solvers and widgets to explore the dynamics of a projectile that is subject to a drag force proportional to the square of its velocity - "quadratic drag".
#
# Where the second term is the drag force, in the direction opposite that of the velocity vector. Re-writing these in terms of the first-order differential equations for vx and vy gives
#
# taking the positive y direction to be down. Notice that these are coupled equations. There are both vx and vy terms in each one. The drag coefficient c depends on the shape and density of the projectile. We can re-write this system of equations in terms of the terminal velocity - the point at which the gravitational force balances the drag force. This happens when mg=cv2.
#
# (a) Create a derivative function to solve this system of equations and use odeint to solve it for a projectile fired at an angle of 50 degrees from the horizontal at an initial speed of 30 m/s. Track the projectile's motion over the time interval of 0 to 200 seconds and let (x0,y0) = (0,0). You'll have to calculate (vx0,vy0) from the information provided. Let vter=44 m/s. Plot the trajectory of the projectile (y vs. x) to see how far the projectile can travel in the x direction before landing.
#
# (b) Now create an interact object that uses sliders for the initial speed, terminal velocity, launch angle, and time. Have it plot two curves - one representing the solution with quadratic drag and the other in the absence of drag:
# x(t)=x0+vx0ty(t)=y0+vy0t−12gt2
#
# (c) Use your interact object to find 3 pairs of initial angle and speed needed for the following projectiles to reach a target 80 m away. How do the values change if there is no air resistance? Put your results in a table for easier reading.

# %%
#a
def projectile(y,t):
    
    g = 9.8
    m = 1.
    vter = 44.
    
    Vxi = y[0]
    Vyi = y[1]
    
    dVxdt = -(g/m)*(Vxi/(vter**2))*np.sqrt(Vxi**2+Vyi**2)
    dVydt = -(g/m)*(1+(Vyi/vter**2)*np.sqrt(Vxi**2+Vyi**2))
    return np.array([ dVxdt, dVydt ])

# %%
Vx0 = 30*np.cos(50.*pi/180.)
Vy0 = 30.*np.sin(50.*pi/180.)

t = np.arange(0.,200.01, .01)
solution = odeint(projectile, np.array([Vx0,Vy0]), t)

Vx = solution[:,0]
Vy = solution[:,1]

x = np.zeros(len(Vx))
y = np.zeros(len(Vy))

x[0] = 0.
y[0] = 0.

for a in range(len(Vx)-1):
    x[a+1] = x[a] + Vx[a] * 0.01
for a in range(len(Vy)-1):
    y[a+1] = y[a] + Vy[a] * 0.01


plt.plot(x,y)
xlim(0,140)
ylim(-140,40)
# Out:
# (-140, 40)

# %%
#b
def Projectile_Motion(v0=30., LA=50., vter=44., time=50., y0=0.):
    def projectile(y,t):
    
        g = 9.8
        m = 1
    
        Vxi = y[0]
        Vyi = y[1]
    
        dVxdt = -(g/m)*(Vxi/(vter**2))*np.sqrt(Vxi**2+Vyi**2)
        dVydt = -(g/m)*(1+(Vyi/vter**2)*np.sqrt(Vxi**2+Vyi**2))
        return np.array([ dVxdt, dVydt ])


    Vx0 = v0*np.cos(LA*pi/180)
    Vy0 = v0*np.sin(LA*pi/180)

    t = np.arange(0.,time+0.01, .01)
    solution = odeint(projectile, np.array([Vx0,Vy0]), t)

    Vx = solution[:,0]
    Vy = solution[:,1]

    x = np.zeros(len(Vx))
    y = np.zeros(len(Vy))

    x[0] = 0.
    y[0] = y0

    for a in range(len(Vx)-1):
        x[a+1] = x[a] + Vx[a] * 0.01
    for a in range(len(Vy)-1):
        y[a+1] = y[a] + Vy[a] * 0.01

    plt.plot(x,y)
    plt.ylim(0,40)
    plt.xlim(0,100)
    plt.title('Drag')
    
    x1 = 0 + Vx0*t
    y1 = y0 + Vy0*t - 0.5*9.8*t**2
    
    plt.figure()
    plt.plot(x1, y1)
    plt.title('No Drag')
    plt.ylim(0,40)
    plt.xlim(0,150)
v = interact(Projectile_Motion, \
             v0=(0.,100.), LA=(0.,90.),vter=(30.,120.), y0 = (0.,10.), time=(1,50))

# %%
#c

class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

table = ListTable()
table.append(['Projectile', 'Terminal Velocity', 'Initial Height', 'Launch Angle', 'Initial Velocity', 'Distance w/o resistance'])
table.append(['Golfball', 44, 0, 50, 33.9, 117])
table.append(['Baseball', 43, 1.5, 50, 33.9, 117])
table.append(['Pumpkin', 107, 1.5, 14.2, 39.9, 83])
table
# Out:
# [['Projectile',
#   'Terminal Velocity',
#   'Initial Height',
#   'Launch Angle',
#   'Initial Velocity',
#   'Distance w/o resistance'],
#  ['Golfball', 44, 0, 50, 33.9, 117],
#  ['Baseball', 43, 1.5, 50, 33.9, 117],
#  ['Pumpkin', 107, 1.5, 14.2, 39.9, 83]]
